# %% [markdown]
# # Importation des packages

# %%
# Importation des packages
import pandas as pd
import numpy as np

# %% [markdown]
# # Création d'un data frame avec pandas

# %%
# Création du dictionnaire
etudiant = {"Prénom":["Donignon","Dotana","Chonny","Dramane","Kadohognon","Nadiala","Charles"]
           ,
           "Nom":["YEO","TUO","KONE","SORO","SILUE","OUATTARA","KOUASSI"],
           "Notes":[19,18,15,13,15,14,16.5]}
etudiant
# Out:
# {'Prénom': ['Donignon',
#   'Dotana',
#   'Chonny',
#   'Dramane',
#   'Kadohognon',
#   'Nadiala',
#   'Charles'],
#  'Nom': ['YEO', 'TUO', 'KONE', 'SORO', 'SILUE', 'OUATTARA', 'KOUASSI'],
#  'Notes': [19, 18, 15, 13, 15, 14, 16.5]}

# %%
# Transformer le dictionnaire en dataframe
df_etudiant=pd.DataFrame(etudiant)
df_etudiant
# Out:
#        Prénom       Nom  Notes
# 0    Donignon       YEO   19.0
# 1      Dotana       TUO   18.0
# 2      Chonny      KONE   15.0
# 3     Dramane      SORO   13.0
# 4  Kadohognon     SILUE   15.0
# 5     Nadiala  OUATTARA   14.0
# 6     Charles   KOUASSI   16.5

# %% [markdown]
# # Création à partir d'un fichier csv/excel

# %%
# Importaion du fichier csv
df=pd.read_csv("credit_risk_dataset.csv",sep=";")
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# 13           14   26     Ngono      Marie  108160             Pret
# 14           15   23      Omar    Mohamed  115000             Pret
# 15           16   32     Petit     Prince  500000     Propriétaire
# 16           17   23   Richard     Arnaud  120000        Locataire
# 17           18   31    Tchana     Albert   92111        Locataire
# 18           19   23  Tchuente       Isis  113000        Locataire
# 19           20   24     Yemba     Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 0              CDI             D            35000         16.02
# 1              CDI             B             1000         11.14
# 2              CDD             C             5500         12.87
# 3              CDI             C            35000         15.23
# 4              CDI             C            35000         14.27
# 5              CDD             A             2500          7.14
# 6              CDI             B            35000         12.42
# 7              CDI             B            35000         11.11
# 8              CDI             A            35000          8.90
# 9              CDI             D             1600         14.74
# 10             CDD             B            35000         10.37
# 11             CDD             A             4500          8.63
# 12             CDI             A            35000          7.90
# 13             CDI             E            35000         18.39
# 14  Entreprenariat             A            35000          7.90
# 15  Entreprenariat             B            30000         10.65
# 16             CDI             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique
# 0                1              0.59      Y                            3
# 1                0              0.10      N                            2
# 2                1              0.57      N                            3
# 3                1              0.53      N                            2
# 4                1              0.55      Y                            4
# 5                1              0.25      N                            2
# 6                1              0.45      N                            3
# 7                1              0.44      N                            4
# 8                1              0.42      N                            2
# 9                1              0.16      N                            3
# 10               1              0.41      N                            4
# 11               1              0.45      N                            2
# 12               1              0.37      N                            2
# 13               1              0.32      N                            4
# 14               0              0.30      N                            4
# 15               0              0.06      N                            3
# 16               0              0.29      N                            4
# 17               1              0.32      N                            4
# 18               1              0.31      N                            4
# 19               1              0.16      N                            2

# %%
# Importation du fichier excel
df=pd.read_excel("credit_dataset_excel.xlsx")
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# 13           14   26     Ngono      Marie  108160             Pret
# 14           15   23      Omar    Mohamed  115000             Pret
# 15           16   32     Petit     Prince  500000     Propriétaire
# 16           17   23   Richard     Arnaud  120000        Locataire
# 17           18   31    Tchana     Albert   92111        Locataire
# 18           19   23  Tchuente       Isis  113000        Locataire
# 19           20   24     Yemba     Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 0              CDI             D            35000         16.02
# 1              CDI             B             1000         11.14
# 2              CDD             C             5500         12.87
# 3              CDI             C            35000         15.23
# 4              CDI             C            35000         14.27
# 5              CDD             A             2500          7.14
# 6              CDI             B            35000         12.42
# 7              CDI             B            35000         11.11
# 8              CDI             A            35000          8.90
# 9              CDI             D             1600         14.74
# 10             CDD             B            35000         10.37
# 11             CDD             A             4500          8.63
# 12             CDI             A            35000          7.90
# 13             CDI             E            35000         18.39
# 14  Entreprenariat             A            35000          7.90
# 15  Entreprenariat             B            30000         10.65
# 16             CDI             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique
# 0                1              0.59      Y                            3
# 1                0              0.10      N                            2
# 2                1              0.57      N                            3
# 3                1              0.53      N                            2
# 4                1              0.55      Y                            4
# 5                1              0.25      N                            2
# 6                1              0.45      N                            3
# 7                1              0.44      N                            4
# 8                1              0.42      N                            2
# 9                1              0.16      N                            3
# 10               1              0.41      N                            4
# 11               1              0.45      N                            2
# 12               1              0.37      N                            2
# 13               1              0.32      N                            4
# 14               0              0.30      N                            4
# 15               0              0.06      N                            3
# 16               0              0.29      N                            4
# 17               1              0.32      N                            4
# 18               1              0.31      N                            4
# 19               1              0.16      N                            2

# %% [markdown]
# # Afficher un dataframe et afficher le type de données et description des colonnes

# %%
# Affichage des 5 premières lignes de notre dataFrame
df.head()
# Out:
#    Id_personne  Age     Nom    Prenom  Revenu Type de domicile Travail  \
# 0            1   40   Akono    Nathan   59000        Locataire     CDI
# 1            2   35    Akwa     Aicha   70000     Propriétaire     CDI
# 2            3   25  Arnaud     Matin    9600        Locataire     CDD
# 3            4   23     Awa     Marie   44000             Pret     CDI
# 4            5   24  Dubois  Lachaise   54400             Pret     CDI
#
#   Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0             D            35000         16.02               1
# 1             B             1000         11.14               0
# 2             C             5500         12.87               1
# 3             C            35000         15.23               1
# 4             C            35000         14.27               1
#
#    Taux_endettement Défaut  Nombre de credit historique
# 0              0.59      Y                            3
# 1              0.10      N                            2
# 2              0.57      N                            3
# 3              0.53      N                            2
# 4              0.55      Y                            4

# %%
#Afficher les 5 dernières lignes de notre dataFrame
df.tail(5)
# Out:
#     Id_personne  Age       Nom  Prenom  Revenu Type de domicile  \
# 15           16   32     Petit  Prince  500000     Propriétaire
# 16           17   23   Richard  Arnaud  120000        Locataire
# 17           18   31    Tchana  Albert   92111        Locataire
# 18           19   23  Tchuente    Isis  113000        Locataire
# 19           20   24     Yemba  Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 15  Entreprenariat             B            30000         10.65
# 16             CDI             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique
# 15               0              0.06      N                            3
# 16               0              0.29      N                            4
# 17               1              0.32      N                            4
# 18               1              0.31      N                            4
# 19               1              0.16      N                            2

# %%
#voir la liste des colonnes du dataframe
df.columns
# Out:
# Index(['Id_personne', 'Age', 'Nom', 'Prenom', 'Revenu', 'Type de domicile',
#        'Travail', 'Grade du pret', 'Montant du prêt', 'Taux_interet',
#        'Statut_du_pret', 'Taux_endettement', 'Défaut',
#        'Nombre de credit historique'],
#       dtype='object')

# %%
#Voir le type de données de ma base de données

df.dtypes
# Out:
# Id_personne                      int64
# Age                              int64
# Nom                             object
# Prenom                          object
# Revenu                           int64
# Type de domicile                object
# Travail                         object
# Grade du pret                   object
# Montant du prêt                  int64
# Taux_interet                   float64
# Statut_du_pret                   int64
# Taux_endettement               float64
# Défaut                          object
# Nombre de credit historique      int64
# dtype: object

# %%
# Voir la dimension du tableau
df.shape
# Out:
# (20, 14)

# %% [markdown]
# # Lecture des tableaux pandas

# %% [markdown]
# ## Sélectionner des colonnes

# %%
#Si la variable n'a pas d'espace
df.Id_personne.head(5)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Id_personne, dtype: int64

# %%
#Si la variable a des caractères spéciaux
df['Type de domicile'].head(5)
# Out:
# 0       Locataire
# 1    Propriétaire
# 2       Locataire
# 3            Pret
# 4            Pret
# Name: Type de domicile, dtype: object

# %%
# Sélectionner plusieurs colonnes
new_df=df[['Type de domicile','Nom']]
new_df.head(4)
# Out:
#   Type de domicile     Nom
# 0        Locataire   Akono
# 1     Propriétaire    Akwa
# 2        Locataire  Arnaud
# 3             Pret     Awa

# %%
#Connaitre les valeurs uniques d'une variable
df['Type de domicile'].unique()
# Out:
# array(['Locataire', 'Propriétaire', 'Pret'], dtype=object)

# %% [markdown]
# # Sélectionner des lignes

# %%
#Sélectionner des lignes qui respectent une condition uniquement
new_cdi=df[df['Travail']=="CDI"]
new_cdi.head(5)
# Out:
#    Id_personne  Age      Nom    Prenom  Revenu Type de domicile Travail  \
# 0            1   40    Akono    Nathan   59000        Locataire     CDI
# 1            2   35     Akwa     Aicha   70000     Propriétaire     CDI
# 3            4   23      Awa     Marie   44000             Pret     CDI
# 4            5   24   Dubois  Lachaise   54400             Pret     CDI
# 6            7   44  Ekounou       Eli   77100     Propriétaire     CDI
#
#   Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0             D            35000         16.02               1
# 1             B             1000         11.14               0
# 3             C            35000         15.23               1
# 4             C            35000         14.27               1
# 6             B            35000         12.42               1
#
#    Taux_endettement Défaut  Nombre de credit historique
# 0              0.59      Y                            3
# 1              0.10      N                            2
# 3              0.53      N                            2
# 4              0.55      Y                            4
# 6              0.45      N                            3

# %%
#Sélectionner des lignes avec plusieurs conditions
new_pret=df[(df['Travail']=="CDI") & (df['Grade du pret']=="D")]
new_pret.head(5)
# Out:
#    Id_personne  Age       Nom  Prenom  Revenu Type de domicile Travail  \
# 0            1   40     Akono  Nathan   59000        Locataire     CDI
# 9           10   50  Mvog-ada  Bertin   80000     Propriétaire     CDI
#
#   Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0             D            35000         16.02               1
# 9             D             1600         14.74               1
#
#    Taux_endettement Défaut  Nombre de credit historique
# 0              0.59      Y                            3
# 9              0.16      N                            3

# %% [markdown]
# # Indexation avec iloc (index location)

# %%
# Sélection de la première ligne
df.iloc[0]
# Out:
# Id_personne                            1
# Age                                   40
# Nom                                Akono
# Prenom                            Nathan
# Revenu                             59000
# Type de domicile               Locataire
# Travail                              CDI
# Grade du pret                          D
# Montant du prêt                    35000
# Taux_interet                       16.02
# Statut_du_pret                         1
# Taux_endettement                    0.59
# Défaut                                 Y
# Nombre de credit historique            3
# Name: 0, dtype: object

# %%
df.iloc[5]
# Out:
# Id_personne                            6
# Age                                   21
# Nom                               Durand
# Prenom                            Bertin
# Revenu                              9900
# Type de domicile               Locataire
# Travail                              CDD
# Grade du pret                          A
# Montant du prêt                     2500
# Taux_interet                        7.14
# Statut_du_pret                         1
# Taux_endettement                    0.25
# Défaut                                 N
# Nombre de credit historique            2
# Name: 5, dtype: object

# %%
df.iloc[16]
# Out:
# Id_personne                           17
# Age                                   23
# Nom                              Richard
# Prenom                            Arnaud
# Revenu                            120000
# Type de domicile               Locataire
# Travail                              CDI
# Grade du pret                          A
# Montant du prêt                    35000
# Taux_interet                         7.9
# Statut_du_pret                         0
# Taux_endettement                    0.29
# Défaut                                 N
# Nombre de credit historique            4
# Name: 16, dtype: object

# %%
# Sélectionner la dernière colone
df.iloc[-1]
# Out:
# Id_personne                        20
# Age                                24
# Nom                             Yemba
# Prenom                         Elodie
# Revenu                          10800
# Type de domicile                 Pret
# Travail                           CDD
# Grade du pret                       B
# Montant du prêt                  1750
# Taux_interet                    10.99
# Statut_du_pret                      1
# Taux_endettement                 0.16
# Défaut                              N
# Nombre de credit historique         2
# Name: 19, dtype: object

# %%
#Sélectionner les deux premières lignes et les deux première colonnes

df.iloc[0:2,0:2]
# Out:
#    Id_personne  Age
# 0            1   40
# 1            2   35

# %% [markdown]
# # Statistiques descriptives

# %% [markdown]
# # Obtenir des statistiques de base (moyenne, médiane, écart-type)

# %%
#Description des variables quantitatives
df.describe()
# Out:
#        Id_personne        Age         Revenu  Montant du prêt  Taux_interet  \
# count     20.00000  20.000000      20.000000        20.000000     20.000000
# mean      10.50000  28.450000   82503.550000     25092.500000     12.253500
# std        5.91608   8.274724  105576.833252     15036.274341      3.899438
# min        1.00000  21.000000    9600.000000      1000.000000      7.140000
# 25%        5.75000  23.000000   24750.000000      5250.000000      8.832500
# 50%       10.50000  24.000000   64500.000000     35000.000000     11.125000
# 75%       15.25000  32.500000   98290.000000     35000.000000     14.862500
# max       20.00000  50.000000  500000.000000     35000.000000     20.250000
#
#        Statut_du_pret  Taux_endettement  Nombre de credit historique
# count       20.000000         20.000000                    20.000000
# mean         0.800000          0.352500                     3.050000
# std          0.410391          0.154507                     0.887041
# min          0.000000          0.060000                     2.000000
# 25%          1.000000          0.280000                     2.000000
# 50%          1.000000          0.345000                     3.000000
# 75%          1.000000          0.450000                     4.000000
# max          1.000000          0.590000                     4.000000

# %% [markdown]
# # Compter les valeurs uniques et les fréquences

# %%
#Description des variables qualitatives
df.describe(include="object")
# Out:
#           Nom  Prenom Type de domicile Travail Grade du pret Défaut
# count      20      20               20      20            20     20
# unique     20      18                3       3             6      2
# top     Akono  Bertin        Locataire     CDI             B      N
# freq        1       2               10      11             6     18

# %%
#Compter les valeurs manquantes par variable
df.isnull().mean()
# Out:
# Id_personne                    0.0
# Age                            0.0
# Nom                            0.0
# Prenom                         0.0
# Revenu                         0.0
# Type de domicile               0.0
# Travail                        0.0
# Grade du pret                  0.0
# Montant du prêt                0.0
# Taux_interet                   0.0
# Statut_du_pret                 0.0
# Taux_endettement               0.0
# Défaut                         0.0
# Nombre de credit historique    0.0
# dtype: float64

# %% [markdown]
# # Modifier les données

# %% [markdown]
# ## Suppression des lignes

# %%
#Suppression des lignes ayant des données manquantes
df.dropna(inplace=True)
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# 13           14   26     Ngono      Marie  108160             Pret
# 14           15   23      Omar    Mohamed  115000             Pret
# 15           16   32     Petit     Prince  500000     Propriétaire
# 16           17   23   Richard     Arnaud  120000        Locataire
# 17           18   31    Tchana     Albert   92111        Locataire
# 18           19   23  Tchuente       Isis  113000        Locataire
# 19           20   24     Yemba     Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 0              CDI             D            35000         16.02
# 1              CDI             B             1000         11.14
# 2              CDD             C             5500         12.87
# 3              CDI             C            35000         15.23
# 4              CDI             C            35000         14.27
# 5              CDD             A             2500          7.14
# 6              CDI             B            35000         12.42
# 7              CDI             B            35000         11.11
# 8              CDI             A            35000          8.90
# 9              CDI             D             1600         14.74
# 10             CDD             B            35000         10.37
# 11             CDD             A             4500          8.63
# 12             CDI             A            35000          7.90
# 13             CDI             E            35000         18.39
# 14  Entreprenariat             A            35000          7.90
# 15  Entreprenariat             B            30000         10.65
# 16             CDI             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique
# 0                1              0.59      Y                            3
# 1                0              0.10      N                            2
# 2                1              0.57      N                            3
# 3                1              0.53      N                            2
# 4                1              0.55      Y                            4
# 5                1              0.25      N                            2
# 6                1              0.45      N                            3
# 7                1              0.44      N                            4
# 8                1              0.42      N                            2
# 9                1              0.16      N                            3
# 10               1              0.41      N                            4
# 11               1              0.45      N                            2
# 12               1              0.37      N                            2
# 13               1              0.32      N                            4
# 14               0              0.30      N                            4
# 15               0              0.06      N                            3
# 16               0              0.29      N                            4
# 17               1              0.32      N                            4
# 18               1              0.31      N                            4
# 19               1              0.16      N                            2

# %% [markdown]
# # Suppression des colonnes

# %%
#Supprimer une colonne

df.drop("Revenu",axis=1)
# Out:
#     Id_personne  Age       Nom     Prenom Type de domicile         Travail  \
# 0             1   40     Akono     Nathan        Locataire             CDI
# 1             2   35      Akwa      Aicha     Propriétaire             CDI
# 2             3   25    Arnaud      Matin        Locataire             CDD
# 3             4   23       Awa      Marie             Pret             CDI
# 4             5   24    Dubois   Lachaise             Pret             CDI
# 5             6   21    Durand     Bertin        Locataire             CDD
# 6             7   44   Ekounou        Eli     Propriétaire             CDI
# 7             8   24   Mendong       Zibi        Locataire             CDI
# 8             9   24    Moussa     Hamado        Locataire             CDI
# 9            10   50  Mvog-ada     Bertin     Propriétaire             CDI
# 10           11   22     Mvogo    Melanie        Locataire             CDD
# 11           12   21      Neba   Charlène        Locataire             CDD
# 12           13   34       Ngo  Stephanie             Pret             CDI
# 13           14   26     Ngono      Marie             Pret             CDI
# 14           15   23      Omar    Mohamed             Pret  Entreprenariat
# 15           16   32     Petit     Prince     Propriétaire  Entreprenariat
# 16           17   23   Richard     Arnaud        Locataire             CDI
# 17           18   31    Tchana     Albert        Locataire             CDD
# 18           19   23  Tchuente       Isis        Locataire  Entreprenariat
# 19           20   24     Yemba     Elodie             Pret             CDD
#
#    Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0              D            35000         16.02               1
# 1              B             1000         11.14               0
# 2              C             5500         12.87               1
# 3              C            35000         15.23               1
# 4              C            35000         14.27               1
# 5              A             2500          7.14               1
# 6              B            35000         12.42               1
# 7              B            35000         11.11               1
# 8              A            35000          8.90               1
# 9              D             1600         14.74               1
# 10             B            35000         10.37               1
# 11             A             4500          8.63               1
# 12             A            35000          7.90               1
# 13             E            35000         18.39               1
# 14             A            35000          7.90               0
# 15             B            30000         10.65               0
# 16             A            35000          7.90               0
# 17             F            35000         20.25               1
# 18             D            35000         18.25               1
# 19             B             1750         10.99               1
#
#     Taux_endettement Défaut  Nombre de credit historique
# 0               0.59      Y                            3
# 1               0.10      N                            2
# 2               0.57      N                            3
# 3               0.53      N                            2
# 4               0.55      Y                            4
# 5               0.25      N                            2
# 6               0.45      N                            3
# 7               0.44      N                            4
# 8               0.42      N                            2
# 9               0.16      N                            3
# 10              0.41      N                            4
# 11              0.45      N                            2
# 12              0.37      N                            2
# 13              0.32      N                            4
# 14              0.30      N                            4
# 15              0.06      N                            3
# 16              0.29      N                            4
# 17              0.32      N                            4
# 18              0.31      N                            4
# 19              0.16      N                            2

# %% [markdown]
# # Créer une nouvelle colonne calculer à partir d'autres

# %%
#Création d'une nouvelle variable comme étant la multiplication de deux colonnes du tableau
df["test"]=df["Montant du prêt"]*df["Taux_interet"]
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# 13           14   26     Ngono      Marie  108160             Pret
# 14           15   23      Omar    Mohamed  115000             Pret
# 15           16   32     Petit     Prince  500000     Propriétaire
# 16           17   23   Richard     Arnaud  120000        Locataire
# 17           18   31    Tchana     Albert   92111        Locataire
# 18           19   23  Tchuente       Isis  113000        Locataire
# 19           20   24     Yemba     Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 0              CDI             D            35000         16.02
# 1              CDI             B             1000         11.14
# 2              CDD             C             5500         12.87
# 3              CDI             C            35000         15.23
# 4              CDI             C            35000         14.27
# 5              CDD             A             2500          7.14
# 6              CDI             B            35000         12.42
# 7              CDI             B            35000         11.11
# 8              CDI             A            35000          8.90
# 9              CDI             D             1600         14.74
# 10             CDD             B            35000         10.37
# 11             CDD             A             4500          8.63
# 12             CDI             A            35000          7.90
# 13             CDI             E            35000         18.39
# 14  Entreprenariat             A            35000          7.90
# 15  Entreprenariat             B            30000         10.65
# 16             CDI             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique  \
# 0                1              0.59      Y                            3
# 1                0              0.10      N                            2
# 2                1              0.57      N                            3
# 3                1              0.53      N                            2
# 4                1              0.55      Y                            4
# 5                1              0.25      N                            2
# 6                1              0.45      N                            3
# 7                1              0.44      N                            4
# 8                1              0.42      N                            2
# 9                1              0.16      N                            3
# 10               1              0.41      N                            4
# 11               1              0.45      N                            2
# 12               1              0.37      N                            2
# 13               1              0.32      N                            4
# 14               0              0.30      N                            4
# 15               0              0.06      N                            3
# 16               0              0.29      N                            4
# 17               1              0.32      N                            4
# 18               1              0.31      N                            4
# 19               1              0.16      N                            2
#
#         test
# 0   560700.0
# 1    11140.0
# 2    70785.0
# 3   533050.0
# 4   499450.0
# 5    17850.0
# 6   434700.0
# 7   388850.0
# 8   311500.0
# 9    23584.0
# 10  362950.0
# 11   38835.0
# 12  276500.0
# 13  643650.0
# 14  276500.0
# 15  319500.0
# 16  276500.0
# 17  708750.0
# 18  638750.0
# 19   19232.5

# %% [markdown]
# # Mettre à jour une colonne

# %%
#Mettre à jour avec une valeur pour toutes les lignes
df["test"]=100
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# 13           14   26     Ngono      Marie  108160             Pret
# 14           15   23      Omar    Mohamed  115000             Pret
# 15           16   32     Petit     Prince  500000     Propriétaire
# 16           17   23   Richard     Arnaud  120000        Locataire
# 17           18   31    Tchana     Albert   92111        Locataire
# 18           19   23  Tchuente       Isis  113000        Locataire
# 19           20   24     Yemba     Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 0              CDI             D            35000         16.02
# 1              CDI             B             1000         11.14
# 2              CDD             C             5500         12.87
# 3              CDI             C            35000         15.23
# 4              CDI             C            35000         14.27
# 5              CDD             A             2500          7.14
# 6              CDI             B            35000         12.42
# 7              CDI             B            35000         11.11
# 8              CDI             A            35000          8.90
# 9              CDI             D             1600         14.74
# 10             CDD             B            35000         10.37
# 11             CDD             A             4500          8.63
# 12             CDI             A            35000          7.90
# 13             CDI             E            35000         18.39
# 14  Entreprenariat             A            35000          7.90
# 15  Entreprenariat             B            30000         10.65
# 16             CDI             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique  test
# 0                1              0.59      Y                            3   100
# 1                0              0.10      N                            2   100
# 2                1              0.57      N                            3   100
# 3                1              0.53      N                            2   100
# 4                1              0.55      Y                            4   100
# 5                1              0.25      N                            2   100
# 6                1              0.45      N                            3   100
# 7                1              0.44      N                            4   100
# 8                1              0.42      N                            2   100
# 9                1              0.16      N                            3   100
# 10               1              0.41      N                            4   100
# 11               1              0.45      N                            2   100
# 12               1              0.37      N                            2   100
# 13               1              0.32      N                            4   100
# 14               0              0.30      N                            4   100
# 15               0              0.06      N                            3   100
# 16               0              0.29      N                            4   100
# 17               1              0.32      N                            4   100
# 18               1              0.31      N                            4   100
# 19               1              0.16      N                            2   100

# %% [markdown]
# # Mettre à jour une valeur

# %%
#Mise à jour de la dernière colonne de la première ligne
df.iloc[0,-1]=100000
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# 13           14   26     Ngono      Marie  108160             Pret
# 14           15   23      Omar    Mohamed  115000             Pret
# 15           16   32     Petit     Prince  500000     Propriétaire
# 16           17   23   Richard     Arnaud  120000        Locataire
# 17           18   31    Tchana     Albert   92111        Locataire
# 18           19   23  Tchuente       Isis  113000        Locataire
# 19           20   24     Yemba     Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 0              CDI             D            35000         16.02
# 1              CDI             B             1000         11.14
# 2              CDD             C             5500         12.87
# 3              CDI             C            35000         15.23
# 4              CDI             C            35000         14.27
# 5              CDD             A             2500          7.14
# 6              CDI             B            35000         12.42
# 7              CDI             B            35000         11.11
# 8              CDI             A            35000          8.90
# 9              CDI             D             1600         14.74
# 10             CDD             B            35000         10.37
# 11             CDD             A             4500          8.63
# 12             CDI             A            35000          7.90
# 13             CDI             E            35000         18.39
# 14  Entreprenariat             A            35000          7.90
# 15  Entreprenariat             B            30000         10.65
# 16             CDI             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique  \
# 0                1              0.59      Y                            3
# 1                0              0.10      N                            2
# 2                1              0.57      N                            3
# 3                1              0.53      N                            2
# 4                1              0.55      Y                            4
# 5                1              0.25      N                            2
# 6                1              0.45      N                            3
# 7                1              0.44      N                            4
# 8                1              0.42      N                            2
# 9                1              0.16      N                            3
# 10               1              0.41      N                            4
# 11               1              0.45      N                            2
# 12               1              0.37      N                            2
# 13               1              0.32      N                            4
# 14               0              0.30      N                            4
# 15               0              0.06      N                            3
# 16               0              0.29      N                            4
# 17               1              0.32      N                            4
# 18               1              0.31      N                            4
# 19               1              0.16      N                            2
#
#       test
# 0   100000
# 1      100
# 2      100
# 3      100
# 4      100
# 5      100
# 6      100
# 7      100
# 8      100
# 9      100
# 10     100
# 11     100
# 12     100
# 13     100
# 14     100
# 15     100
# 16     100
# 17     100
# 18     100
# 19     100

# %% [markdown]
# # Mettre à jour des valeurs qui respectent une condition

# %%
#Modifier la valeur de la colonne d'une ligne en fonction d'une condition (remplacer D par F loan_grade)

df.loc[df["Travail"]=="CDI","Travail"]="CDD"
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# 13           14   26     Ngono      Marie  108160             Pret
# 14           15   23      Omar    Mohamed  115000             Pret
# 15           16   32     Petit     Prince  500000     Propriétaire
# 16           17   23   Richard     Arnaud  120000        Locataire
# 17           18   31    Tchana     Albert   92111        Locataire
# 18           19   23  Tchuente       Isis  113000        Locataire
# 19           20   24     Yemba     Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 0              CDD             D            35000         16.02
# 1              CDD             B             1000         11.14
# 2              CDD             C             5500         12.87
# 3              CDD             C            35000         15.23
# 4              CDD             C            35000         14.27
# 5              CDD             A             2500          7.14
# 6              CDD             B            35000         12.42
# 7              CDD             B            35000         11.11
# 8              CDD             A            35000          8.90
# 9              CDD             D             1600         14.74
# 10             CDD             B            35000         10.37
# 11             CDD             A             4500          8.63
# 12             CDD             A            35000          7.90
# 13             CDD             E            35000         18.39
# 14  Entreprenariat             A            35000          7.90
# 15  Entreprenariat             B            30000         10.65
# 16             CDD             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique  \
# 0                1              0.59      Y                            3
# 1                0              0.10      N                            2
# 2                1              0.57      N                            3
# 3                1              0.53      N                            2
# 4                1              0.55      Y                            4
# 5                1              0.25      N                            2
# 6                1              0.45      N                            3
# 7                1              0.44      N                            4
# 8                1              0.42      N                            2
# 9                1              0.16      N                            3
# 10               1              0.41      N                            4
# 11               1              0.45      N                            2
# 12               1              0.37      N                            2
# 13               1              0.32      N                            4
# 14               0              0.30      N                            4
# 15               0              0.06      N                            3
# 16               0              0.29      N                            4
# 17               1              0.32      N                            4
# 18               1              0.31      N                            4
# 19               1              0.16      N                            2
#
#       test
# 0   100000
# 1      100
# 2      100
# 3      100
# 4      100
# 5      100
# 6      100
# 7      100
# 8      100
# 9      100
# 10     100
# 11     100
# 12     100
# 13     100
# 14     100
# 15     100
# 16     100
# 17     100
# 18     100
# 19     100

# %% [markdown]
# # Fusion et jointure de Data Frames

# %%
# Création des DataFrames exemple
data1 = {
    "ID": [1, 2, 3, 4],
    "Prénom": ["Alice", "Bob", "Charlie", "David"]
}

data2 = {
    "ID": [3, 4, 5, 6],
    "Ville": ["Paris", "Lyon", "Marseille", "Toulouse"]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Effectuer une jointure interne (inner join)
inner_join = df1.merge(df2, on="ID", how="inner")

# Effectuer une jointure externe (outer join)
outer_join = df1.merge(df2, on="ID", how="outer")

# Effectuer une jointure gauche (left join)
left_join = df1.merge(df2, on="ID", how="left")

# Effectuer une jointure droite (right join)
right_join = df1.merge(df2, on="ID", how="right")

# Afficher les résultats
print("Inner join:")
print(inner_join)
print("\nOuter join:")
print(outer_join)
print("\nLeft join:")
print(left_join)
print("\nRight join:")
print(right_join)
# Out:
# Inner join:
#    ID   Prénom  Ville
# 0   3  Charlie  Paris
# 1   4    David   Lyon
#
# Outer join:
#    ID   Prénom      Ville
# 0   1    Alice        NaN
# 1   2      Bob        NaN
# 2   3  Charlie      Paris
# 3   4    David       Lyon
# 4   5      NaN  Marseille
# 5   6      NaN   Toulouse
#
# Left join:
#    ID   Prénom  Ville
# 0   1    Alice    NaN
# 1   2      Bob    NaN
# 2   3  Charlie  Paris
# 3   4    David   Lyon
#
# Right join:
#    ID   Prénom      Ville
# 0   3  Charlie      Paris
# 1   4    David       Lyon
# 2   5      NaN  Marseille
# 3   6      NaN   Toulouse
